# %%
import pandas as pd
import random
import ast
from collections import defaultdict

# %%
syl_pairs = {0: ['A', 'B'], 1: ['B', 'C'], 2: ['C', 'D'], 3: ['C', 'G'], 4: ['C', 'J'], 
            5: ['D', 'E'], 6: ['E', 'F'], 7: ['F', 'G'], 8: ['F', 'A'], 9: ['F', 'J'], 
            10: ['G', 'H'], 11: ['H', 'I'], 12: ['I', 'J'], 13: ['I', 'A'], 14: ['I', 'D'],
            15: ['J', 'K'], 16: ['K', 'L'], 17: ['L', 'A'], 18: ['L', 'D'], 19: ['L', 'G']}
words = {0: ['A', 'B', 'C'], 1: ['D', 'E', 'F'], 2: ['G', 'H', 'I'], 3: ['J', 'K', 'L'], 4: ['A', 'B', 'C'], 5: ['D', 'E', 'F'], 6: ['G', 'H', 'I'], 7: ['J', 'K', 'L'],
         8: ['A', 'B', 'C'], 9: ['D', 'E', 'F'], 10: ['G', 'H', 'I'], 11: ['J', 'K', 'L'], 12: ['A', 'B', 'C'], 13: ['D', 'E', 'F'], 14: ['G', 'H', 'I'], 15: ['J', 'K', 'L'],
            16: ['A', 'B', 'C'], 17: ['D', 'E', 'F'], 18: ['G', 'H', 'I'], 19: ['J', 'K', 'L'], 20: ['A', 'B', 'C'], 21: ['D', 'E', 'F'], 22: ['G', 'H', 'I'], 23: ['J', 'K', 'L'],
            24: ['A', 'B', 'C'], 25: ['D', 'E', 'F'], 26: ['G', 'H', 'I'], 27: ['J', 'K', 'L'], 28: ['A', 'B', 'C'], 29: ['D', 'E', 'F'], 30: ['G', 'H', 'I'], 31: ['J', 'K', 'L'],
            32: ['A', 'B', 'C'], 33: ['D', 'E', 'F'], 34: ['G', 'H', 'I'], 35: ['J', 'K', 'L'], 36: ['A', 'B', 'C'], 37: ['D', 'E', 'F'], 38: ['G', 'H', 'I'], 39: ['J', 'K', 'L'],
            40: ['A', 'B', 'C'], 41: ['D', 'E', 'F'], 42: ['G', 'H', 'I'], 43: ['J', 'K', 'L'], 44: ['A', 'B', 'C'], 45: ['D', 'E', 'F'], 46: ['G', 'H', 'I'], 47: ['J', 'K', 'L'],
            48: ['A', 'B', 'C'], 49: ['D', 'E', 'F'], 50: ['G', 'H', 'I'], 51: ['J', 'K', 'L'], 52: ['A', 'B', 'C'], 53: ['D', 'E', 'F'], 54: ['G', 'H', 'I'], 55: ['J', 'K', 'L'],
            56: ['A', 'B', 'C'], 57: ['D', 'E', 'F'], 58: ['G', 'H', 'I'], 59: ['J', 'K', 'L'], 60: ['A', 'B', 'C'], 61: ['D', 'E', 'F'], 62: ['G', 'H', 'I'], 63: ['J', 'K', 'L'],
            64: ['A', 'B', 'C'], 65: ['D', 'E', 'F'], 66: ['G', 'H', 'I'], 67: ['J', 'K', 'L'], 68: ['A', 'B', 'C'], 69: ['D', 'E', 'F'], 70: ['G', 'H', 'I'], 71: ['J', 'K', 'L'],
            72: ['A', 'B', 'C'], 73: ['D', 'E', 'F'], 74: ['G', 'H', 'I'], 75: ['J', 'K', 'L'], 76: ['A', 'B', 'C'], 77: ['D', 'E', 'F'], 78: ['G', 'H', 'I'], 79: ['J', 'K', 'L'],
            80: ['A', 'B', 'C'], 81: ['D', 'E', 'F'], 82: ['G', 'H', 'I'], 83: ['J', 'K', 'L'], 84: ['A', 'B', 'C'], 85: ['D', 'E', 'F'], 86: ['G', 'H', 'I'], 87: ['J', 'K', 'L'],
            88: ['A', 'B', 'C'], 89: ['D', 'E', 'F'], 90: ['G', 'H', 'I'], 91: ['J', 'K', 'L'], 92: ['A', 'B', 'C'], 93: ['D', 'E', 'F'], 94: ['G', 'H', 'I'], 95: ['J', 'K', 'L'],
            96: ['A', 'B', 'C'], 97: ['D', 'E', 'F'], 98: ['G', 'H', 'I'], 99: ['J', 'K', 'L'], 100: ['A', 'B', 'C'], 101: ['D', 'E', 'F'], 102: ['G', 'H', 'I'], 103: ['J', 'K', 'L'],
            104: ['A', 'B', 'C'], 105: ['D', 'E', 'F'], 106: ['G', 'H', 'I'], 107: ['J', 'K', 'L'], 108: ['A', 'B', 'C'], 109: ['D', 'E', 'F'], 110: ['G', 'H', 'I'], 111: ['J', 'K', 'L'],
            112: ['A', 'B', 'C'], 113: ['D', 'E', 'F'], 114: ['G', 'H', 'I'], 115: ['J', 'K', 'L'], 116: ['A', 'B', 'C'], 117: ['D', 'E', 'F'], 118: ['G', 'H', 'I'], 119: ['J', 'K', 'L'],
            120: ['A', 'B', 'C'], 121: ['D', 'E', 'F'], 122: ['G', 'H', 'I'], 123: ['J', 'K', 'L'], 124: ['A', 'B', 'C'], 125: ['D', 'E', 'F'], 126: ['G', 'H', 'I'], 127: ['J', 'K', 'L'],
            128: ['A', 'B', 'C'], 129: ['D', 'E', 'F'], 130: ['G', 'H', 'I'], 131: ['J', 'K', 'L'], 132: ['A', 'B', 'C'], 133: ['D', 'E', 'F'], 134: ['G', 'H', 'I'], 135: ['J', 'K', 'L'],
            136: ['A', 'B', 'C'], 137: ['D', 'E', 'F'], 138: ['G', 'H', 'I'], 139: ['J', 'K', 'L'], 140: ['A', 'B', 'C'], 141: ['D', 'E', 'F'], 142: ['G', 'H', 'I'], 143: ['J', 'K', 'L'],
            144: ['A', 'B', 'C'], 145: ['D', 'E', 'F'], 146: ['G', 'H', 'I'], 147: ['J', 'K', 'L'], 148: ['A', 'B', 'C'], 149: ['D', 'E', 'F'], 150: ['G', 'H', 'I'], 151: ['J', 'K', 'L'],
            152: ['A', 'B', 'C'], 153: ['D', 'E', 'F'], 154: ['G', 'H', 'I'], 155: ['J', 'K', 'L'], 156: ['A', 'B', 'C'], 157: ['D', 'E', 'F'], 158: ['G', 'H', 'I'], 159: ['J', 'K', 'L'],
            160: ['A', 'B', 'C'], 161: ['D', 'E', 'F'], 162: ['G', 'H', 'I'], 163: ['J', 'K', 'L'], 164: ['A', 'B', 'C'], 165: ['D', 'E', 'F'], 166: ['G', 'H', 'I'], 167: ['J', 'K', 'L'],
            168: ['A', 'B', 'C'], 169: ['D', 'E', 'F'], 170: ['G', 'H', 'I'], 171: ['J', 'K', 'L'], 172: ['A', 'B', 'C'], 173: ['D', 'E', 'F'], 174: ['G', 'H', 'I'], 175: ['J', 'K', 'L'],
            176: ['A', 'B', 'C'], 177: ['D', 'E', 'F'], 178: ['G', 'H', 'I'], 179: ['J', 'K', 'L'], 180: ['A', 'B', 'C'], 181: ['D', 'E', 'F'], 182: ['G', 'H', 'I'], 183: ['J', 'K', 'L'],
            184: ['A', 'B', 'C'], 185: ['D', 'E', 'F'], 186: ['G', 'H', 'I'], 187: ['J', 'K', 'L'], 188: ['A', 'B', 'C'], 189: ['D', 'E', 'F'], 190: ['G', 'H', 'I'], 191: ['J', 'K', 'L'],
            }

metric_patterns = pd.read_csv('stim_conditions/combo_chart_6.csv')

simple_patterns = [[int(x) for x in ast.literal_eval(pattern)] for pattern in metric_patterns['simple'].dropna().tolist()]
complex_patterns = [[int(x) for x in ast.literal_eval(pattern)] for pattern in metric_patterns['complex'].dropna().tolist()]
simple_silence_patterns = [[int(x) for x in ast.literal_eval(pattern)] for pattern in metric_patterns['simple_silence'].dropna().tolist()]
complex_silence_patterns = [[int(x) for x in ast.literal_eval(pattern)] for pattern in metric_patterns['complex_silence'].dropna().tolist()]
syllables = list(words.values())

# %%
def interweave(syllables, silence_pattern):
    forbidden_patterns = [('F', 'D'), ('C', 'A'), ('I', 'G'), ('L', 'J'), ('A', 'C'), ('B', 'D'), ('C', 'E'), ('D', 'F'), ('E', 'G'), ('F', 'H'), ('G', 'I'), ('H', 'J'), ('I', 'K'), ('J', 'L'),
                      ('', 'A'), ('', 'B'), ('', 'C'), ('', 'D'), ('', 'E'), ('', 'F'), ('', 'G'), ('', 'H'), ('', 'I'), ('', 'J'), ('', 'K'), ('', 'L'),
                      ('A', ''), ('B', ''), ('C', ''), ('D', ''), ('E', ''), ('F', ''), ('G', ''), ('H', ''), ('I', ''), ('J', ''), ('K', ''), ('L', ''),
                      ('A'), ('B'), ('C'), ('D'), ('E'), ('F'), ('G'), ('H'), ('I'), ('J'), ('K'), ('L')]

    syllables = [sublist for item in syllables for sublist in item]
    interweaved = [val for pair in zip(syllables, silence_pattern) for val in pair]
    interweaved = [interweaved[i] for i in range(len(interweaved)) if i == 0 or interweaved[i] != interweaved[i-1]]
    while any(pattern in zip(interweaved[::2], interweaved[1::2]) for pattern in forbidden_patterns):
        syllables = [sublist for item in syllables for sublist in item]
        interweaved = [val for pair in zip(syllables, silence_pattern) for val in pair]
        interweaved = [interweaved[i] for i in range(len(interweaved)) if i == 0 or interweaved[i] != interweaved[i-1]]

    return interweaved

def pick_pattern_template_and_syllables(condition, syllables):
    syllables = list(syllables)
    random.shuffle(syllables)
    
    if condition == 'simple':
        simple_pattern_1 = random.choice(simple_patterns); simple_pattern_2 = random.choice(simple_patterns); simple_pattern_3 = random.choice(simple_patterns); simple_pattern_4 = random.choice(simple_patterns)
        simple_pattern_5 = random.choice(simple_patterns); simple_pattern_6 = random.choice(simple_patterns); simple_pattern_7 = random.choice(simple_patterns); simple_pattern_8 = random.choice(simple_patterns)
        simple_pattern_9 = random.choice(simple_patterns); simple_pattern_10 = random.choice(simple_patterns); simple_pattern_11 = random.choice(simple_patterns); simple_pattern_12 = random.choice(simple_patterns)
        simple_pattern_13 = random.choice(simple_patterns); simple_pattern_14 = random.choice(simple_patterns); simple_pattern_15 = random.choice(simple_patterns); simple_pattern_16 = random.choice(simple_patterns)
        simple_pattern_17 = random.choice(simple_patterns); simple_pattern_18 = random.choice(simple_patterns); simple_pattern_19 = random.choice(simple_patterns); simple_pattern_20 = random.choice(simple_patterns)
        simple_pattern_21 = random.choice(simple_patterns); simple_pattern_22 = random.choice(simple_patterns); simple_pattern_23 = random.choice(simple_patterns); simple_pattern_24 = random.choice(simple_patterns)
        simple_pattern_25 = random.choice(simple_patterns); simple_pattern_26 = random.choice(simple_patterns); simple_pattern_27 = random.choice(simple_patterns); simple_pattern_28 = random.choice(simple_patterns)
        simple_pattern_29 = random.choice(simple_patterns); simple_pattern_30 = random.choice(simple_patterns); simple_pattern_31 = random.choice(simple_patterns); simple_pattern_32 = random.choice(simple_patterns)
        simple_pattern_33 = random.choice(simple_patterns); simple_pattern_34 = random.choice(simple_patterns); simple_pattern_35 = random.choice(simple_patterns); simple_pattern_36 = random.choice(simple_patterns)
        simple_pattern_37 = random.choice(simple_patterns); simple_pattern_38 = random.choice(simple_patterns); simple_pattern_39 = random.choice(simple_patterns); simple_pattern_40 = random.choice(simple_patterns)
        simple_pattern_41 = random.choice(simple_patterns); simple_pattern_42 = random.choice(simple_patterns); simple_pattern_43 = random.choice(simple_patterns); simple_pattern_44 = random.choice(simple_patterns)
        simple_pattern_45 = random.choice(simple_patterns); simple_pattern_46 = random.choice(simple_patterns); simple_pattern_47 = random.choice(simple_patterns); simple_pattern_48 = random.choice(simple_patterns)
        simple_pattern_49 = random.choice(simple_patterns); simple_pattern_50 = random.choice(simple_patterns); simple_pattern_51 = random.choice(simple_patterns); simple_pattern_52 = random.choice(simple_patterns)
        simple_pattern_53 = random.choice(simple_patterns); simple_pattern_54 = random.choice(simple_patterns); simple_pattern_55 = random.choice(simple_patterns); simple_pattern_56 = random.choice(simple_patterns)
        simple_pattern_57 = random.choice(simple_patterns); simple_pattern_58 = random.choice(simple_patterns); simple_pattern_59 = random.choice(simple_patterns); simple_pattern_60 = random.choice(simple_patterns)
        simple_pattern_61 = random.choice(simple_patterns); simple_pattern_62 = random.choice(simple_patterns); simple_pattern_63 = random.choice(simple_patterns); simple_pattern_64 = random.choice(simple_patterns)
        simple_pattern_65 = random.choice(simple_patterns); simple_pattern_66 = random.choice(simple_patterns); simple_pattern_67 = random.choice(simple_patterns); simple_pattern_68 = random.choice(simple_patterns)
        simple_pattern_69 = random.choice(simple_patterns); simple_pattern_70 = random.choice(simple_patterns); simple_pattern_71 = random.choice(simple_patterns); simple_pattern_72 = random.choice(simple_patterns)
        simple_pattern_73 = random.choice(simple_patterns); simple_pattern_74 = random.choice(simple_patterns); simple_pattern_75 = random.choice(simple_patterns); simple_pattern_76 = random.choice(simple_patterns)
        simple_pattern_77 = random.choice(simple_patterns); simple_pattern_78 = random.choice(simple_patterns); simple_pattern_79 = random.choice(simple_patterns); simple_pattern_80 = random.choice(simple_patterns)
        simple_pattern_81 = random.choice(simple_patterns); simple_pattern_82 = random.choice(simple_patterns); simple_pattern_83 = random.choice(simple_patterns); simple_pattern_84 = random.choice(simple_patterns)
        simple_pattern_85 = random.choice(simple_patterns); simple_pattern_86 = random.choice(simple_patterns); simple_pattern_87 = random.choice(simple_patterns); simple_pattern_88 = random.choice(simple_patterns)
        simple_pattern_89 = random.choice(simple_patterns); simple_pattern_90 = random.choice(simple_patterns); simple_pattern_91 = random.choice(simple_patterns); simple_pattern_92 = random.choice(simple_patterns)
        simple_pattern_93 = random.choice(simple_patterns); simple_pattern_94 = random.choice(simple_patterns); simple_pattern_95 = random.choice(simple_patterns); simple_pattern_96 = random.choice(simple_patterns)

        silence_pattern_1 = random.choice(simple_silence_patterns); silence_pattern_2 = random.choice(simple_silence_patterns); silence_pattern_3 = random.choice(simple_silence_patterns); silence_pattern_4 = random.choice(simple_silence_patterns)
        silence_pattern_5 = random.choice(simple_silence_patterns); silence_pattern_6 = random.choice(simple_silence_patterns); silence_pattern_7 = random.choice(simple_silence_patterns); silence_pattern_8 = random.choice(simple_silence_patterns)
        silence_pattern_9 = random.choice(simple_silence_patterns); silence_pattern_10 = random.choice(simple_silence_patterns); silence_pattern_11 = random.choice(simple_silence_patterns); silence_pattern_12 = random.choice(simple_silence_patterns)
        silence_pattern_13 = random.choice(simple_silence_patterns); silence_pattern_14 = random.choice(simple_silence_patterns); silence_pattern_15 = random.choice(simple_silence_patterns); silence_pattern_16 = random.choice(simple_silence_patterns)
        silence_pattern_17 = random.choice(simple_silence_patterns); silence_pattern_18 = random.choice(simple_silence_patterns); silence_pattern_19 = random.choice(simple_silence_patterns); silence_pattern_20 = random.choice(simple_silence_patterns)
        silence_pattern_21 = random.choice(simple_silence_patterns); silence_pattern_22 = random.choice(simple_silence_patterns); silence_pattern_23 = random.choice(simple_silence_patterns); silence_pattern_24 = random.choice(simple_silence_patterns)
        silence_pattern_25 = random.choice(simple_silence_patterns); silence_pattern_26 = random.choice(simple_silence_patterns); silence_pattern_27 = random.choice(simple_silence_patterns); silence_pattern_28 = random.choice(simple_silence_patterns)
        silence_pattern_29 = random.choice(simple_silence_patterns); silence_pattern_30 = random.choice(simple_silence_patterns); silence_pattern_31 = random.choice(simple_silence_patterns); silence_pattern_32 = random.choice(simple_silence_patterns)
        silence_pattern_33 = random.choice(simple_silence_patterns); silence_pattern_34 = random.choice(simple_silence_patterns); silence_pattern_35 = random.choice(simple_silence_patterns); silence_pattern_36 = random.choice(simple_silence_patterns)
        silence_pattern_37 = random.choice(simple_silence_patterns); silence_pattern_38 = random.choice(simple_silence_patterns); silence_pattern_39 = random.choice(simple_silence_patterns); silence_pattern_40 = random.choice(simple_silence_patterns)
        silence_pattern_41 = random.choice(simple_silence_patterns); silence_pattern_42 = random.choice(simple_silence_patterns); silence_pattern_43 = random.choice(simple_silence_patterns); silence_pattern_44 = random.choice(simple_silence_patterns)
        silence_pattern_45 = random.choice(simple_silence_patterns); silence_pattern_46 = random.choice(simple_silence_patterns); silence_pattern_47 = random.choice(simple_silence_patterns); silence_pattern_48 = random.choice(simple_silence_patterns)
        silence_pattern_49 = random.choice(simple_silence_patterns); silence_pattern_50 = random.choice(simple_silence_patterns); silence_pattern_51 = random.choice(simple_silence_patterns); silence_pattern_52 = random.choice(simple_silence_patterns)
        silence_pattern_53 = random.choice(simple_silence_patterns); silence_pattern_54 = random.choice(simple_silence_patterns); silence_pattern_55 = random.choice(simple_silence_patterns); silence_pattern_56 = random.choice(simple_silence_patterns)
        silence_pattern_57 = random.choice(simple_silence_patterns); silence_pattern_58 = random.choice(simple_silence_patterns); silence_pattern_59 = random.choice(simple_silence_patterns); silence_pattern_60 = random.choice(simple_silence_patterns)
        silence_pattern_61 = random.choice(simple_silence_patterns); silence_pattern_62 = random.choice(simple_silence_patterns); silence_pattern_63 = random.choice(simple_silence_patterns); silence_pattern_64 = random.choice(simple_silence_patterns)
        silence_pattern_65 = random.choice(simple_silence_patterns); silence_pattern_66 = random.choice(simple_silence_patterns); silence_pattern_67 = random.choice(simple_silence_patterns); silence_pattern_68 = random.choice(simple_silence_patterns)
        silence_pattern_69 = random.choice(simple_silence_patterns); silence_pattern_70 = random.choice(simple_silence_patterns); silence_pattern_71 = random.choice(simple_silence_patterns); silence_pattern_72 = random.choice(simple_silence_patterns)
        silence_pattern_73 = random.choice(simple_silence_patterns); silence_pattern_74 = random.choice(simple_silence_patterns); silence_pattern_75 = random.choice(simple_silence_patterns); silence_pattern_76 = random.choice(simple_silence_patterns)
        silence_pattern_77 = random.choice(simple_silence_patterns); silence_pattern_78 = random.choice(simple_silence_patterns); silence_pattern_79 = random.choice(simple_silence_patterns); silence_pattern_80 = random.choice(simple_silence_patterns)
        silence_pattern_81 = random.choice(simple_silence_patterns); silence_pattern_82 = random.choice(simple_silence_patterns); silence_pattern_83 = random.choice(simple_silence_patterns); silence_pattern_84 = random.choice(simple_silence_patterns)
        silence_pattern_85 = random.choice(simple_silence_patterns); silence_pattern_86 = random.choice(simple_silence_patterns); silence_pattern_87 = random.choice(simple_silence_patterns); silence_pattern_88 = random.choice(simple_silence_patterns)
        silence_pattern_89 = random.choice(simple_silence_patterns); silence_pattern_90 = random.choice(simple_silence_patterns); silence_pattern_91 = random.choice(simple_silence_patterns); silence_pattern_92 = random.choice(simple_silence_patterns)
        silence_pattern_93 = random.choice(simple_silence_patterns); silence_pattern_94 = random.choice(simple_silence_patterns); silence_pattern_95 = random.choice(simple_silence_patterns); silence_pattern_96 = random.choice(simple_silence_patterns)

        pattern = (simple_pattern_1 + simple_pattern_2 + simple_pattern_3 + simple_pattern_4 
                   + simple_pattern_5 + simple_pattern_6 + simple_pattern_7 + simple_pattern_8
                   + simple_pattern_9 + simple_pattern_10 + simple_pattern_11 + simple_pattern_12
                   + simple_pattern_13 + simple_pattern_14 + simple_pattern_15 + simple_pattern_16
                   + simple_pattern_17 + simple_pattern_18 + simple_pattern_19 + simple_pattern_20
                   + simple_pattern_21 + simple_pattern_22 + simple_pattern_23 + simple_pattern_24
                   + simple_pattern_25 + simple_pattern_26 + simple_pattern_27 + simple_pattern_28
                   + simple_pattern_29 + simple_pattern_30 + simple_pattern_31 + simple_pattern_32
                   + simple_pattern_33 + simple_pattern_34 + simple_pattern_35 + simple_pattern_36
                   + simple_pattern_37 + simple_pattern_38 + simple_pattern_39 + simple_pattern_40
                   + simple_pattern_41 + simple_pattern_42 + simple_pattern_43 + simple_pattern_44
                   + simple_pattern_45 + simple_pattern_46 + simple_pattern_47 + simple_pattern_48
                   + simple_pattern_49 + simple_pattern_50 + simple_pattern_51 + simple_pattern_52
                   + simple_pattern_53 + simple_pattern_54 + simple_pattern_55 + simple_pattern_56
                   + simple_pattern_57 + simple_pattern_58 + simple_pattern_59 + simple_pattern_60
                   + simple_pattern_61 + simple_pattern_62 + simple_pattern_63 + simple_pattern_64
                   + simple_pattern_65 + simple_pattern_66 + simple_pattern_67 + simple_pattern_68
                   + simple_pattern_69 + simple_pattern_70 + simple_pattern_71 + simple_pattern_72
                   + simple_pattern_73 + simple_pattern_74 + simple_pattern_75 + simple_pattern_76
                   + simple_pattern_77 + simple_pattern_78 + simple_pattern_79 + simple_pattern_80
                   + simple_pattern_81 + simple_pattern_82 + simple_pattern_83 + simple_pattern_84
                   + simple_pattern_85 + simple_pattern_86 + simple_pattern_87 + simple_pattern_88
                   + simple_pattern_89 + simple_pattern_90 + simple_pattern_91 + simple_pattern_92
                   + simple_pattern_93 + simple_pattern_94 + simple_pattern_95 + simple_pattern_96)
        silence_pattern = (silence_pattern_1 + silence_pattern_2 + silence_pattern_3 + silence_pattern_4 
                           + silence_pattern_5 + silence_pattern_6 + silence_pattern_7 + silence_pattern_8
                           + silence_pattern_9 + silence_pattern_10 + silence_pattern_11 + silence_pattern_12
                           + silence_pattern_13 + silence_pattern_14 + silence_pattern_15 + silence_pattern_16
                           + silence_pattern_17 + silence_pattern_18 + silence_pattern_19 + silence_pattern_20
                           + silence_pattern_21 + silence_pattern_22 + silence_pattern_23 + silence_pattern_24
                           + silence_pattern_25 + silence_pattern_26 + silence_pattern_27 + silence_pattern_28
                           + silence_pattern_29 + silence_pattern_30 + silence_pattern_31 + silence_pattern_32
                           + silence_pattern_33 + silence_pattern_34 + silence_pattern_35 + silence_pattern_36
                           + silence_pattern_37 + silence_pattern_38 + silence_pattern_39 + silence_pattern_40
                           + silence_pattern_41 + silence_pattern_42 + silence_pattern_43 + silence_pattern_44
                           + silence_pattern_45 + silence_pattern_46 + silence_pattern_47 + silence_pattern_48
                           + silence_pattern_49 + silence_pattern_50 + silence_pattern_51 + silence_pattern_52
                           + silence_pattern_53 + silence_pattern_54 + silence_pattern_55 + silence_pattern_56
                           + silence_pattern_57 + silence_pattern_58 + silence_pattern_59 + silence_pattern_60
                           + silence_pattern_61 + silence_pattern_62 + silence_pattern_63 + silence_pattern_64
                           + silence_pattern_65 + silence_pattern_66 + silence_pattern_67 + silence_pattern_68
                            + silence_pattern_69 + silence_pattern_70 + silence_pattern_71 + silence_pattern_72
                            + silence_pattern_73 + silence_pattern_74 + silence_pattern_75 + silence_pattern_76
                            + silence_pattern_77 + silence_pattern_78 + silence_pattern_79 + silence_pattern_80
                            + silence_pattern_81 + silence_pattern_82 + silence_pattern_83 + silence_pattern_84
                            + silence_pattern_85 + silence_pattern_86 + silence_pattern_87 + silence_pattern_88
                            + silence_pattern_89 + silence_pattern_90 + silence_pattern_91 + silence_pattern_92
                            + silence_pattern_93 + silence_pattern_94 + silence_pattern_95 + silence_pattern_96)
    
    else:
        complex_pattern_1 = random.choice(complex_patterns); complex_pattern_2 = random.choice(complex_patterns); complex_pattern_3 = random.choice(complex_patterns); complex_pattern_4 = random.choice(complex_patterns)
        complex_pattern_5 = random.choice(complex_patterns); complex_pattern_6 = random.choice(complex_patterns); complex_pattern_7 = random.choice(complex_patterns); complex_pattern_8 = random.choice(complex_patterns)
        complex_pattern_9 = random.choice(complex_patterns); complex_pattern_10 = random.choice(complex_patterns); complex_pattern_11 = random.choice(complex_patterns); complex_pattern_12 = random.choice(complex_patterns)
        complex_pattern_13 = random.choice(complex_patterns); complex_pattern_14 = random.choice(complex_patterns); complex_pattern_15 = random.choice(complex_patterns); complex_pattern_16 = random.choice(complex_patterns)
        complex_pattern_17 = random.choice(complex_patterns); complex_pattern_18 = random.choice(complex_patterns); complex_pattern_19 = random.choice(complex_patterns); complex_pattern_20 = random.choice(complex_patterns)
        complex_pattern_21 = random.choice(complex_patterns); complex_pattern_22 = random.choice(complex_patterns); complex_pattern_23 = random.choice(complex_patterns); complex_pattern_24 = random.choice(complex_patterns)
        complex_pattern_25 = random.choice(complex_patterns); complex_pattern_26 = random.choice(complex_patterns); complex_pattern_27 = random.choice(complex_patterns); complex_pattern_28 = random.choice(complex_patterns)
        complex_pattern_29 = random.choice(complex_patterns); complex_pattern_30 = random.choice(complex_patterns); complex_pattern_31 = random.choice(complex_patterns); complex_pattern_32 = random.choice(complex_patterns)
        complex_pattern_33 = random.choice(complex_patterns); complex_pattern_34 = random.choice(complex_patterns); complex_pattern_35 = random.choice(complex_patterns); complex_pattern_36 = random.choice(complex_patterns)
        complex_pattern_37 = random.choice(complex_patterns); complex_pattern_38 = random.choice(complex_patterns); complex_pattern_39 = random.choice(complex_patterns); complex_pattern_40 = random.choice(complex_patterns)
        complex_pattern_41 = random.choice(complex_patterns); complex_pattern_42 = random.choice(complex_patterns); complex_pattern_43 = random.choice(complex_patterns); complex_pattern_44 = random.choice(complex_patterns)
        complex_pattern_45 = random.choice(complex_patterns); complex_pattern_46 = random.choice(complex_patterns); complex_pattern_47 = random.choice(complex_patterns); complex_pattern_48 = random.choice(complex_patterns)
        complex_pattern_49 = random.choice(complex_patterns); complex_pattern_50 = random.choice(complex_patterns); complex_pattern_51 = random.choice(complex_patterns); complex_pattern_52 = random.choice(complex_patterns)
        complex_pattern_53 = random.choice(complex_patterns); complex_pattern_54 = random.choice(complex_patterns); complex_pattern_55 = random.choice(complex_patterns); complex_pattern_56 = random.choice(complex_patterns)
        complex_pattern_57 = random.choice(complex_patterns); complex_pattern_58 = random.choice(complex_patterns); complex_pattern_59 = random.choice(complex_patterns); complex_pattern_60 = random.choice(complex_patterns)
        complex_pattern_61 = random.choice(complex_patterns); complex_pattern_62 = random.choice(complex_patterns); complex_pattern_63 = random.choice(complex_patterns); complex_pattern_64 = random.choice(complex_patterns)
        complex_pattern_65 = random.choice(complex_patterns); complex_pattern_66 = random.choice(complex_patterns); complex_pattern_67 = random.choice(complex_patterns); complex_pattern_68 = random.choice(complex_patterns)
        complex_pattern_69 = random.choice(complex_patterns); complex_pattern_70 = random.choice(complex_patterns); complex_pattern_71 = random.choice(complex_patterns); complex_pattern_72 = random.choice(complex_patterns)
        complex_pattern_73 = random.choice(complex_patterns); complex_pattern_74 = random.choice(complex_patterns); complex_pattern_75 = random.choice(complex_patterns); complex_pattern_76 = random.choice(complex_patterns)
        complex_pattern_77 = random.choice(complex_patterns); complex_pattern_78 = random.choice(complex_patterns); complex_pattern_79 = random.choice(complex_patterns); complex_pattern_80 = random.choice(complex_patterns)
        complex_pattern_81 = random.choice(complex_patterns); complex_pattern_82 = random.choice(complex_patterns); complex_pattern_83 = random.choice(complex_patterns); complex_pattern_84 = random.choice(complex_patterns)
        complex_pattern_85 = random.choice(complex_patterns); complex_pattern_86 = random.choice(complex_patterns); complex_pattern_87 = random.choice(complex_patterns); complex_pattern_88 = random.choice(complex_patterns)
        complex_pattern_89 = random.choice(complex_patterns); complex_pattern_90 = random.choice(complex_patterns); complex_pattern_91 = random.choice(complex_patterns); complex_pattern_92 = random.choice(complex_patterns)
        complex_pattern_93 = random.choice(complex_patterns); complex_pattern_94 = random.choice(complex_patterns); complex_pattern_95 = random.choice(complex_patterns); complex_pattern_96 = random.choice(complex_patterns)

        silence_pattern_1 = random.choice(complex_silence_patterns); silence_pattern_2 = random.choice(complex_silence_patterns); silence_pattern_3 = random.choice(complex_silence_patterns); silence_pattern_4 = random.choice(complex_silence_patterns)
        silence_pattern_5 = random.choice(complex_silence_patterns); silence_pattern_6 = random.choice(complex_silence_patterns); silence_pattern_7 = random.choice(complex_silence_patterns); silence_pattern_8 = random.choice(complex_silence_patterns)
        silence_pattern_9 = random.choice(complex_silence_patterns); silence_pattern_10 = random.choice(complex_silence_patterns); silence_pattern_11 = random.choice(complex_silence_patterns); silence_pattern_12 = random.choice(complex_silence_patterns)
        silence_pattern_13 = random.choice(complex_silence_patterns); silence_pattern_14 = random.choice(complex_silence_patterns); silence_pattern_15 = random.choice(complex_silence_patterns); silence_pattern_16 = random.choice(complex_silence_patterns)
        silence_pattern_17 = random.choice(complex_silence_patterns); silence_pattern_18 = random.choice(complex_silence_patterns); silence_pattern_19 = random.choice(complex_silence_patterns); silence_pattern_20 = random.choice(complex_silence_patterns)
        silence_pattern_21 = random.choice(complex_silence_patterns); silence_pattern_22 = random.choice(complex_silence_patterns); silence_pattern_23 = random.choice(complex_silence_patterns); silence_pattern_24 = random.choice(complex_silence_patterns)
        silence_pattern_25 = random.choice(complex_silence_patterns); silence_pattern_26 = random.choice(complex_silence_patterns); silence_pattern_27 = random.choice(complex_silence_patterns); silence_pattern_28 = random.choice(complex_silence_patterns)
        silence_pattern_29 = random.choice(complex_silence_patterns); silence_pattern_30 = random.choice(complex_silence_patterns); silence_pattern_31 = random.choice(complex_silence_patterns); silence_pattern_32 = random.choice(complex_silence_patterns)
        silence_pattern_33 = random.choice(complex_silence_patterns); silence_pattern_34 = random.choice(complex_silence_patterns); silence_pattern_35 = random.choice(complex_silence_patterns); silence_pattern_36 = random.choice(complex_silence_patterns)
        silence_pattern_37 = random.choice(complex_silence_patterns); silence_pattern_38 = random.choice(complex_silence_patterns); silence_pattern_39 = random.choice(complex_silence_patterns); silence_pattern_40 = random.choice(complex_silence_patterns)
        silence_pattern_41 = random.choice(complex_silence_patterns); silence_pattern_42 = random.choice(complex_silence_patterns); silence_pattern_43 = random.choice(complex_silence_patterns); silence_pattern_44 = random.choice(complex_silence_patterns)
        silence_pattern_45 = random.choice(complex_silence_patterns); silence_pattern_46 = random.choice(complex_silence_patterns); silence_pattern_47 = random.choice(complex_silence_patterns); silence_pattern_48 = random.choice(complex_silence_patterns)
        silence_pattern_49 = random.choice(complex_silence_patterns); silence_pattern_50 = random.choice(complex_silence_patterns); silence_pattern_51 = random.choice(complex_silence_patterns); silence_pattern_52 = random.choice(complex_silence_patterns)
        silence_pattern_53 = random.choice(complex_silence_patterns); silence_pattern_54 = random.choice(complex_silence_patterns); silence_pattern_55 = random.choice(complex_silence_patterns); silence_pattern_56 = random.choice(complex_silence_patterns)
        silence_pattern_57 = random.choice(complex_silence_patterns); silence_pattern_58 = random.choice(complex_silence_patterns); silence_pattern_59 = random.choice(complex_silence_patterns); silence_pattern_60 = random.choice(complex_silence_patterns)
        silence_pattern_61 = random.choice(complex_silence_patterns); silence_pattern_62 = random.choice(complex_silence_patterns); silence_pattern_63 = random.choice(complex_silence_patterns); silence_pattern_64 = random.choice(complex_silence_patterns)
        silence_pattern_65 = random.choice(complex_silence_patterns); silence_pattern_66 = random.choice(complex_silence_patterns); silence_pattern_67 = random.choice(complex_silence_patterns); silence_pattern_68 = random.choice(complex_silence_patterns)
        silence_pattern_69 = random.choice(complex_silence_patterns); silence_pattern_70 = random.choice(complex_silence_patterns); silence_pattern_71 = random.choice(complex_silence_patterns); silence_pattern_72 = random.choice(complex_silence_patterns)
        silence_pattern_73 = random.choice(complex_silence_patterns); silence_pattern_74 = random.choice(complex_silence_patterns); silence_pattern_75 = random.choice(complex_silence_patterns); silence_pattern_76 = random.choice(complex_silence_patterns)
        silence_pattern_77 = random.choice(complex_silence_patterns); silence_pattern_78 = random.choice(complex_silence_patterns); silence_pattern_79 = random.choice(complex_silence_patterns); silence_pattern_80 = random.choice(complex_silence_patterns)
        silence_pattern_81 = random.choice(complex_silence_patterns); silence_pattern_82 = random.choice(complex_silence_patterns); silence_pattern_83 = random.choice(complex_silence_patterns); silence_pattern_84 = random.choice(complex_silence_patterns)
        silence_pattern_85 = random.choice(complex_silence_patterns); silence_pattern_86 = random.choice(complex_silence_patterns); silence_pattern_87 = random.choice(complex_silence_patterns); silence_pattern_88 = random.choice(complex_silence_patterns)
        silence_pattern_89 = random.choice(complex_silence_patterns); silence_pattern_90 = random.choice(complex_silence_patterns); silence_pattern_91 = random.choice(complex_silence_patterns); silence_pattern_92 = random.choice(complex_silence_patterns)
        silence_pattern_93 = random.choice(complex_silence_patterns); silence_pattern_94 = random.choice(complex_silence_patterns); silence_pattern_95 = random.choice(complex_silence_patterns); silence_pattern_96 = random.choice(complex_silence_patterns)
        
        pattern = (complex_pattern_1 + complex_pattern_2 + complex_pattern_3 + complex_pattern_4 
                   + complex_pattern_5 + complex_pattern_6 + complex_pattern_7 + complex_pattern_8
                   + complex_pattern_9 + complex_pattern_10 + complex_pattern_11 + complex_pattern_12
                   + complex_pattern_13 + complex_pattern_14 + complex_pattern_15 + complex_pattern_16
                   + complex_pattern_17 + complex_pattern_18 + complex_pattern_19 + complex_pattern_20
                   + complex_pattern_21 + complex_pattern_22 + complex_pattern_23 + complex_pattern_24
                   + complex_pattern_25 + complex_pattern_26 + complex_pattern_27 + complex_pattern_28
                   + complex_pattern_29 + complex_pattern_30 + complex_pattern_31 + complex_pattern_32
                   + complex_pattern_33 + complex_pattern_34 + complex_pattern_35 + complex_pattern_36
                   + complex_pattern_37 + complex_pattern_38 + complex_pattern_39 + complex_pattern_40
                   + complex_pattern_41 + complex_pattern_42 + complex_pattern_43 + complex_pattern_44
                   + complex_pattern_45 + complex_pattern_46 + complex_pattern_47 + complex_pattern_48
                   + complex_pattern_49 + complex_pattern_50 + complex_pattern_51 + complex_pattern_52
                   + complex_pattern_53 + complex_pattern_54 + complex_pattern_55 + complex_pattern_56
                   + complex_pattern_57 + complex_pattern_58 + complex_pattern_59 + complex_pattern_60
                   + complex_pattern_61 + complex_pattern_62 + complex_pattern_63 + complex_pattern_64
                   + complex_pattern_65 + complex_pattern_66 + complex_pattern_67 + complex_pattern_68
                   + complex_pattern_69 + complex_pattern_70 + complex_pattern_71 + complex_pattern_72
                   + complex_pattern_73 + complex_pattern_74 + complex_pattern_75 + complex_pattern_76
                   + complex_pattern_77 + complex_pattern_78 + complex_pattern_79 + complex_pattern_80
                   + complex_pattern_81 + complex_pattern_82 + complex_pattern_83 + complex_pattern_84
                   + complex_pattern_85 + complex_pattern_86 + complex_pattern_87 + complex_pattern_88
                   + complex_pattern_89 + complex_pattern_90 + complex_pattern_91 + complex_pattern_92
                   + complex_pattern_93 + complex_pattern_94 + complex_pattern_95 + complex_pattern_96)
        silence_pattern = (silence_pattern_1 + silence_pattern_2 + silence_pattern_3 + silence_pattern_4 
                           + silence_pattern_5 + silence_pattern_6 + silence_pattern_7 + silence_pattern_8
                           + silence_pattern_9 + silence_pattern_10 + silence_pattern_11 + silence_pattern_12
                           + silence_pattern_13 + silence_pattern_14 + silence_pattern_15 + silence_pattern_16
                           + silence_pattern_17 + silence_pattern_18 + silence_pattern_19 + silence_pattern_20
                           + silence_pattern_21 + silence_pattern_22 + silence_pattern_23 + silence_pattern_24
                           + silence_pattern_25 + silence_pattern_26 + silence_pattern_27 + silence_pattern_28
                           + silence_pattern_29 + silence_pattern_30 + silence_pattern_31 + silence_pattern_32
                           + silence_pattern_33 + silence_pattern_34 + silence_pattern_35 + silence_pattern_36
                           + silence_pattern_37 + silence_pattern_38 + silence_pattern_39 + silence_pattern_40
                           + silence_pattern_41 + silence_pattern_42 + silence_pattern_43 + silence_pattern_44
                           + silence_pattern_45 + silence_pattern_46 + silence_pattern_47 + silence_pattern_48
                           + silence_pattern_49 + silence_pattern_50 + silence_pattern_51 + silence_pattern_52
                           + silence_pattern_53 + silence_pattern_54 + silence_pattern_55 + silence_pattern_56
                           + silence_pattern_57 + silence_pattern_58 + silence_pattern_59 + silence_pattern_60
                           + silence_pattern_61 + silence_pattern_62 + silence_pattern_63 + silence_pattern_64
                           + silence_pattern_65 + silence_pattern_66 + silence_pattern_67 + silence_pattern_68
                            + silence_pattern_69 + silence_pattern_70 + silence_pattern_71 + silence_pattern_72
                            + silence_pattern_73 + silence_pattern_74 + silence_pattern_75 + silence_pattern_76
                            + silence_pattern_77 + silence_pattern_78 + silence_pattern_79 + silence_pattern_80
                            + silence_pattern_81 + silence_pattern_82 + silence_pattern_83 + silence_pattern_84
                            + silence_pattern_85 + silence_pattern_86 + silence_pattern_87 + silence_pattern_88
                            + silence_pattern_89 + silence_pattern_90 + silence_pattern_91 + silence_pattern_92
                            + silence_pattern_93 + silence_pattern_94 + silence_pattern_95 + silence_pattern_96)

    interweaved = interweave(syllables, silence_pattern)
    print('interweaved:', interweaved)
    print('pattern:', pattern)
    return pattern, interweaved

# %%
df_combos = pd.DataFrame(columns=['Interweaved'])

for i in range(1):
    condition = 'simple'
    pattern, interweaved = pick_pattern_template_and_syllables(condition, syllables)
    df_combos = df_combos._append({'Interweaved': interweaved}, ignore_index=True)

frequency_table = {letter: defaultdict(int) for letter in 'ABCDEFGHIJKL'}
interweaved = df_combos['Interweaved'].tolist()

for sequence in interweaved:
    for i in range(0, len(sequence), 2):
        letter = sequence[i]
        silence_value = sequence[i+1]
        frequency_table[letter][silence_value] += 1

df = pd.DataFrame(frequency_table).T
df = df.fillna(0)
df = df.astype(int)
frequency_table = defaultdict(lambda: defaultdict(int))

forbidden_patterns = [('F', 'D'), ('C', 'A'), ('I', 'G'), ('L', 'J'), ('A', 'C'), ('B', 'D'), ('C', 'E'), ('D', 'F'), ('E', 'G'), ('F', 'H'), ('G', 'I'), ('H', 'J'), ('I', 'K'), ('J', 'L'),
                      ('', 'A'), ('', 'B'), ('', 'C'), ('', 'D'), ('', 'E'), ('', 'F'), ('', 'G'), ('', 'H'), ('', 'I'), ('', 'J'), ('', 'K'), ('', 'L'),
                      ('A', ''), ('B', ''), ('C', ''), ('D', ''), ('E', ''), ('F', ''), ('G', ''), ('H', ''), ('I', ''), ('J', ''), ('K', ''), ('L', ''),
                      ('A'), ('B'), ('C'), ('D'), ('E'), ('F'), ('G'), ('H'), ('I'), ('J'), ('K'), ('L')]

for _, row in df_combos.iterrows():
    sequence = row['Interweaved']
    for i in range(0, len(sequence) - 2, 2):
        current_pair = (sequence[i], sequence[i+2])
        if all(isinstance(item, str) for item in current_pair) and current_pair not in forbidden_patterns:
            silence_value = sequence[i+1]
            frequency_table[current_pair][silence_value] += 1

df = pd.DataFrame(frequency_table).T
df = df.fillna(0)
df = df.sort_index(axis=1)
# df = df.sort_index(axis=0)
df['Total'] = df.sum(axis=1)
df = df.sort_values(by='Total', ascending=False)
display(df, clear=True)
# Out:
#         0     1     2     3  Total
# G H  19.0  14.0   5.0  10.0   48.0
# D E  14.0  17.0  11.0   6.0   48.0
# H I  16.0  24.0   7.0   1.0   48.0
# A B  17.0  16.0   8.0   7.0   48.0
# E F  23.0  16.0   9.0   0.0   48.0
# B C  20.0  15.0  13.0   0.0   48.0
# K L  22.0  13.0  13.0   0.0   48.0
# J K  18.0  12.0   8.0  10.0   48.0
# C J   4.0   9.0   2.0   4.0   19.0
# I A   9.0   1.0   3.0   1.0   14.0
# L D   5.0   5.0   3.0   0.0   13.0
# F A   4.0   5.0   0.0   4.0   13.0
# C D   7.0   2.0   0.0   2.0   11.0
# L G   3.0   1.0   3.0   4.0   11.0
# F G   4.0   4.0   2.0   1.0   11.0
# L A   5.0   3.0   1.0   0.0    9.0
# I D   6.0   3.0   0.0   0.0    9.0
# F J   1.0   2.0   4.0   1.0    8.0
# I J   2.0   2.0   0.0   2.0    6.0
# C G   0.0   1.0   2.0   3.0    6.0

# %%
len(df)
# Out:
# 20

# %%
df_combos_com = pd.DataFrame(columns=['Interweaved'])

for i in range(1):
    condition = 'complex'
    pattern, interweaved = pick_pattern_template_and_syllables(condition, syllables)
    df_combos_com = df_combos_com._append({'Interweaved': interweaved}, ignore_index=True)

frequency_table = {letter: defaultdict(int) for letter in 'ABCDEFGHIJKL'}
interweaved = df_combos_com['Interweaved'].tolist()

for sequence in interweaved:
    for i in range(0, len(sequence), 2):
        letter = sequence[i]
        silence_value = sequence[i+1]
        frequency_table[letter][silence_value] += 1

df = pd.DataFrame(frequency_table).T
df = df.fillna(0)
df = df.astype(int)
frequency_table = defaultdict(lambda: defaultdict(int))

forbidden_patterns = [('F', 'D'), ('C', 'A'), ('I', 'G'), ('L', 'J'), ('A', 'C'), ('B', 'D'), ('C', 'E'), ('D', 'F'), ('E', 'G'), ('F', 'H'), ('G', 'I'), ('H', 'J'), ('I', 'K'), ('J', 'L'),
                      ('', 'A'), ('', 'B'), ('', 'C'), ('', 'D'), ('', 'E'), ('', 'F'), ('', 'G'), ('', 'H'), ('', 'I'), ('', 'J'), ('', 'K'), ('', 'L'),
                      ('A', ''), ('B', ''), ('C', ''), ('D', ''), ('E', ''), ('F', ''), ('G', ''), ('H', ''), ('I', ''), ('J', ''), ('K', ''), ('L', ''),
                      ('A'), ('B'), ('C'), ('D'), ('E'), ('F'), ('G'), ('H'), ('I'), ('J'), ('K'), ('L')]

for _, row in df_combos_com.iterrows():
    sequence = row['Interweaved']
    for i in range(0, len(sequence) - 2, 2):
        current_pair = (sequence[i], sequence[i+2])
        if all(isinstance(item, str) for item in current_pair) and current_pair not in forbidden_patterns:
            silence_value = sequence[i+1]
            frequency_table[current_pair][silence_value] += 1

df = pd.DataFrame(frequency_table).T
df = df.fillna(0)
df = df.sort_index(axis=1)
# df = df.sort_index(axis=0)
df['Total'] = df.sum(axis=1)
df = df.sort_values(by='Total', ascending=False)
display(df, clear=True)
# Out:
#         0     1     2     3  Total
# A B  22.0  10.0  12.0   4.0   48.0
# G H  14.0  17.0   7.0  10.0   48.0
# B C  18.0  15.0   8.0   7.0   48.0
# J K  19.0  15.0   9.0   5.0   48.0
# H I  24.0  10.0   7.0   7.0   48.0
# K L  16.0  14.0   9.0   9.0   48.0
# E F  17.0  13.0   9.0   9.0   48.0
# D E  22.0  14.0   8.0   4.0   48.0
# L G   8.0   5.0   4.0   0.0   17.0
# I J   7.0   6.0   2.0   0.0   15.0
# F J   9.0   4.0   2.0   0.0   15.0
# C D   8.0   3.0   2.0   0.0   13.0
# L D   2.0   5.0   2.0   3.0   12.0
# F A   2.0   3.0   6.0   0.0   11.0
# I A   4.0   6.0   0.0   1.0   11.0
# C G   4.0   4.0   3.0   0.0   11.0
# L A   2.0   4.0   1.0   2.0    9.0
# I D   1.0   6.0   1.0   0.0    8.0
# C J   4.0   2.0   2.0   0.0    8.0
# F G   3.0   3.0   1.0   0.0    7.0

# %%
df_combos.to_csv('stim_conditions/simple_combos.csv', index=False)
df_combos_com.to_csv('stim_conditions/complex_combos.csv', index=False)
